# %%
#@title Default title text
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import preprocessing



data = pd.read_csv('/content/sample_data/odev_tenis.csv')

from sklearn import preprocessing
data2= data.apply(preprocessing.LabelEncoder().fit_transform) #constructor dan bir obje tanımla ve apply et, yani bütün columnlara  fit_transform u uygula.
#false = 0 , true = 1 , no = 0 , yes = 1
#print(data2)

c = data2.iloc[:,:1]#satirlarin hepsini al - 1e kadar olan columnları al
ohe = preprocessing.OneHotEncoder()
c = ohe.fit_transform(c).toarray()
#print(c)

weather = pd.DataFrame(data=c, index = range(14), columns=['overcast','rainy','sunny'])
latestData= pd.concat([weather, data.iloc[:,1:3]], axis=1)

#print(weather)#hava durumlarının 0-1 olarak ifade edilmis sekli
#print(latestData)#datanin son hali

latestData= pd.concat([data2.iloc[:,-2:],latestData], axis=1)
#print(latestData)

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(latestData.iloc[:,:-1],latestData.iloc[:,-1:], test_size=0.33, random_state=0)

from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(x_train, y_train)

y_pred = reg.predict(x_test)
print(y_pred)
'''
print(x_test)
print(y_test)
print(x_train)
print(y_train)
print(y_pred)
'''

#backward elimination
import statsmodels.api as sm

X = np.append(arr=np.ones((14,1)).astype(int), values = latestData.iloc[:,:-1], axis=1)

X_l = latestData.iloc[:,[0,1,2,3,4,5]].values
X_l = np.array(X_l,dtype=float)
model = sm.OLS(latestData.iloc[:,-1:],X_l).fit()
#print(model.summary())

latestData= latestData.iloc[:,1:]
#print(latestData)

import statsmodels.api as sm

X = np.append(arr=np.ones((14,1)).astype(int), values = latestData.iloc[:,:-1], axis=1)

X_l = latestData.iloc[:,[0,1,2,3,4,5]].values
X_l = np.array(X_l,dtype=float)
model = sm.OLS(latestData.iloc[:,-1:],X_l).fit()
#print(model.summary())

x_train = x_train.iloc[:,1:]
x_test = x_test.iloc[:,1:]

reg.fit(x_train, y_train)
y_pred = reg.predict(x_test)

print(y_test)

print(y_pred)#bu tahmin humidity e daha yakın.
# Out:
# [[84.45365573]
#  [63.93839954]
#  [85.76050662]
#  [64.21013241]
#  [75.06793322]]
#     humidity
# 8         70
# 6         65
# 4         80
# 11        90
# 2         86
# [[77.98135142]
#  [68.29304916]
#  [81.05037539]
#  [71.44926132]
#  [75.78905304]]
